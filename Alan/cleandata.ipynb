# %%
import pandas as pd
import string

# read data csv
data = pd.read_csv("dataset.csv")

print(data)
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
# drop track_id column
data = data.drop("track_id", axis=1)

print(data)
# Out:
#         Unnamed: 0                 artists  \
# 0                0             Gen Hoshino
# 1                1            Ben Woodward
# 2                2  Ingrid Michaelson;ZAYN
# 3                3            Kina Grannis
# 4                4        Chord Overstreet
# ...            ...                     ...
# 113995      113995           Rainy Lullaby
# 113996      113996           Rainy Lullaby
# 113997      113997           Cesária Evora
# 113998      113998        Michael W. Smith
# 113999      113999           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# ...

# %%
# drop rows with popularity 0
data = data[data['popularity'] != 0]

# fix the index of the resulting dataframe
data.reset_index(drop=True, inplace=True)
 
print(data)
# Out:
#        Unnamed: 0                 artists  \
# 0               0             Gen Hoshino
# 1               1            Ben Woodward
# 2               2  Ingrid Michaelson;ZAYN
# 3               3            Kina Grannis
# 4               4        Chord Overstreet
# ...           ...                     ...
# 97975      113995           Rainy Lullaby
# 97976      113996           Rainy Lullaby
# 97977      113997           Cesária Evora
# 97978      113998        Michael W. Smith
# 97979      113999           Cesária Evora
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# ...

# %%
def contains_non_english(text):
    pattern = r'[^\x00-\x7F]+'
    return bool(re.search(pattern, text))

# Filter rows that contain non-English characters and drop them
data = data[~data['track_name'].apply(contains_non_english)].reset_index(drop=True)
print(data)
# Out:
#        Unnamed: 0                 artists  \
# 0               0             Gen Hoshino
# 1               1            Ben Woodward
# 2               2  Ingrid Michaelson;ZAYN
# 3               3            Kina Grannis
# 4               4        Chord Overstreet
# ...           ...                     ...
# 83877      113995           Rainy Lullaby
# 83878      113996           Rainy Lullaby
# 83879      113997           Cesária Evora
# 83880      113998        Michael W. Smith
# 83881      113999           Cesária Evora
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# ...

# %%
def contains_non_english(text):
    pattern = r'[^\x00-\x7F]+'
    return bool(re.search(pattern, text))

# Filter rows that contain non-English characters and drop them
data = data[~data['artists'].apply(contains_non_english)].reset_index(drop=True)
print(data)
# Out:
#        Unnamed: 0                 artists  \
# 0               0             Gen Hoshino
# 1               1            Ben Woodward
# 2               2  Ingrid Michaelson;ZAYN
# 3               3            Kina Grannis
# 4               4        Chord Overstreet
# ...           ...                     ...
# 79497      113992           Jesus Culture
# 79498      113993            Chris Tomlin
# 79499      113995           Rainy Lullaby
# 79500      113996           Rainy Lullaby
# 79501      113998        Michael W. Smith
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# ...

# %%
def contains_non_english(text):
    pattern = r'[^\x00-\x7F]+'
    return bool(re.search(pattern, text))

# Filter rows that contain non-English characters and drop them
data = data[~data['album_name'].apply(contains_non_english)].reset_index(drop=True)
print(data)
# Out:
#        Unnamed: 0                 artists  \
# 0               0             Gen Hoshino
# 1               1            Ben Woodward
# 2               2  Ingrid Michaelson;ZAYN
# 3               3            Kina Grannis
# 4               4        Chord Overstreet
# ...           ...                     ...
# 75789      113992           Jesus Culture
# 75790      113993            Chris Tomlin
# 75791      113995           Rainy Lullaby
# 75792      113996           Rainy Lullaby
# 75793      113998        Michael W. Smith
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                Hold On
# ...                                                  ...
# ...

# %%
data = data.sort_values("popularity")
top_data = data.head(10000)
print(top_data)
# Out:
#        Unnamed: 0                    artists              album_name  \
# 49183       71276                   Wage War      Release Your ANGER
# 47665       68219            Jhayco;Anuel AA  Reggaeton Mix Perreito
# 47666       68220            Jhayco;Anuel AA    Reggeaton Imperdible
# 47668       68223                     Jhayco       Frescura y Perreo
# 47670       68233               Jhayco;Ozuna  Hora del taco sin auto
# ...           ...                        ...                     ...
# 4703         6818            Mord'a'Stigmata  Dreams of Quiet Places
# 4705         6822                   Enslaved                 Riitiir
# 4706         6824  Wolves In The Throne Room               Celestite
# 29775       42272                  Iron Lung         Cold Storage II
# 20308       27891                  Dimension        Hospitality 2016
#
#                    track_name  popularity  duration_ms  explicit  \
# 49183                     Low           1       227093     False
# ...
